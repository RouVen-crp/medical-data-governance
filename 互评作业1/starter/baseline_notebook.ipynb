# %% [markdown]
# # 医疗数据治理作业 Starter Notebook
#
# 这个 notebook 是学生的起点模板。
#
# 建议流程：
# 1. 读取 `data_dictionary.md`
# 2. 探索 `train_unlabeled.csv`
# 3. 在 `starter/lf_template.py` 中修改 LF
# 4. 使用 `starter/evaluation.py` 评估结果

# %%
from pathlib import Path

data_dir = Path('..')
print('Starter notebook loaded from', data_dir.resolve())
